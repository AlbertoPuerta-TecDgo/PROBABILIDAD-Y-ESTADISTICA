# %% [markdown]
# <a href="https://colab.research.google.com/github/AlbertoPuerta-TecDgo/PROBABILIDAD-Y-ESTADISTICA/blob/main/Unidad1/Practica_1_y_2%20y%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)
# #INSTITUTO TECNOLÓGICO DE DURANGO
# #Probabilidad y estadística
# #Unidad 1
# #Practica 1. Estadistica descriptiva básica e Histogramas.
# Quezada Puerta Jesús Alberto

# %%
# Lista de calificaciones del grupo de probabilidad y estadistica.
grupoa = [70, 80, 80, 80, 90, 90, 100, 100,77, 88, 88, 99]
print(grupoa)
# Out:
# [70, 80, 80, 80, 90, 90, 100, 100, 77, 88, 88, 99]

# %%
from statistics import *

# %%
# La funcion type nos dice el tipo de dato que es una variable.
type (grupoa)
# Out:
# list

# %%
# SACAR LA MEDIA DE LAS CALIFICACIONE CON UNA FORMULA.
#La funcion len nos regresa el numero de elementos que hay en una lista.
promedio = sum(grupoa)/len(grupoa)
print (promedio)
# Out:
# 86.83333333333333

# %%
# Utilizar la funcion mean que esta en la libreria "Statistics" para sacar el promedio
promedio0=mean(grupoa)
print (promedio0)
# Out:
# 86.83333333333333

# %%
#Determinar el valor de la mediana con la funcion median
mediana = median (grupoa)
print (mediana)
# Out:
# 88.0

# %%
#Determinar el valor de la moda con la funciomn mode.
# La moda es el valor que más se repite.
from statistics import mode # Make sure mode is imported

moda = mode(grupoa)
print(moda)
# Out:
# 80

# %%
#Determinar el valor de la moda con la funciomn mode.
# La moda es el valor que más se repite.
from statistics import mode # Make sure mode is imported

moda = mode(grupoa)
print(moda)
# Out:
# 80

# %%
#  Definas una variable llamada Tiempos100mts de tipo lista, que contiene los
# tioempos que tardaron los 10 alumnos para correr los 00 metros.
tiempos100mts = [ 15.10, 17.20, 14.69, 13.27, 22.15, 18.7, 19.5, 20.65, 15.10, 17.20]

# Desplegamos los valores de la lista
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.7, 19.5, 20.65, 15.1, 17.2]

# %%
#En caso de que exista mas de una moda, se puede emplear la funcion multimode para sacar todas las midas que puedan existir.
moda2 = multimode(grupoa)
print(moda2)
# Out:
# [80]

# %%
# USAMOS LA FUNCION MEDIAN PARA DETERMINAR EL TIEMPO PROMEDIO DE LA LISTA DE VALORE.
# SE DEFINE UNA NUEVA VARIABLE PARA CALCULAR LA MODA.
mediana = median(tiempos100mts)
print("La media de los tiempos de los corredores es=>", mediana)
# Out:
# La media de los tiempos de los corredores es=> 17.2

# %%
import random

# %%
import matplotlib.pyplot as plt

# %%
fabrica1 = []
for i in range(100):
    numero_aleatorio1 = round (random.uniform(50, 100),2)
    fabrica1.append(numero_aleatorio1)
print(fabrica1)
# Out:
# [55.83, 72.2, 88.06, 95.56, 94.3, 56.01, 54.74, 55.87, 97.51, 52.63, 64.77, 66.11, 62.08, 92.84, 56.64, 91.5, 82.53, 63.36, 79.59, 87.27, 67.57, 70.01, 78.89, 61.25, 95.9, 51.42, 77.79, 55.45, 92.84, 94.21, 90.25, 75.88, 77.18, 66.8, 71.94, 80.36, 81.97, 62.59, 89.89, 87.62, 62.74, 54.49, 93.84, 96.58, 93.81, 59.15, 64.5, 58.4, 69.74, 72.68, 91.7, 52.08, 56.95, 78.19, 68.9, 93.9, 78.1, 98.41, 98.4, 89.1, 79.73, 66.46, 99.46, 53.4, 72.87, 89.26, 82.49, 60.47, 63.16, 65.49, 91.3, 79.04, 69.8, 96.19, 83.7, 98.3, 51.58, 58.92, 78.44, 95.95, 82.4, 99.88, 72.46, 62.9, 65.32, 58.12, 61.73, 93.73, 61.67, 82.14, 65.43, 58.27, 86.91, 89.88, 77.47, 75.9, 93.83, 50.76, 94.37, 76.79]

# %%
plt.hist(fabrica1)
plt.title("Produccion de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion de la fabrica 1')

# %%
import matplotlib.pyplot as plt

# %%
import random

# %%
fabrica2= []
for i in range(100):
  numero_aleatorio2 = round (random.uniform(50, 100),2)
  fabrica2.append(numero_aleatorio2)
  print(fabrica2)
# Out:
# [86.52]
# [86.52, 95.64]
# [86.52, 95.64, 75.38]
# [86.52, 95.64, 75.38, 55.26]
# [86.52, 95.64, 75.38, 55.26, 50.57]
# [86.52, 95.64, 75.38, 55.26, 50.57, 92.47]
# [86.52, 95.64, 75.38, 55.26, 50.57, 92.47, 98.93]
# [86.52, 95.64, 75.38, 55.26, 50.57, 92.47, 98.93, 92.5]
# [86.52, 95.64, 75.38, 55.26, 50.57, 92.47, 98.93, 92.5, 61.69]
# [86.52, 95.64, 75.38, 55.26, 50.57, 92.47, 98.93, 92.5, 61.69, 77.31]
# [86.52, 95.64, 75.38, 55.26, 50.57, 92.47, 98.93, 92.5, 61.69, 77.31, 79.42]
# [86.52, 95.64, 75.38, 55.26, 50.57, 92.47, 98.93, 92.5, 61.69, 77.31, 79.42, 70.25]
# [86.52, 95.64, 75.38, 55.26, 50.57, 92.47, 98.93, 92.5, 61.69, 77.31, 79.42, 70.25, 88.72]
# [86.52, 95.64, 75.38, 55.26, 50.57, 92.47, 98.93, 92.5, 61.69, 77.31, 79.42, 70.25, 88.72, 67.76]
# [86.52, 95.64, 75.38, 55.26, 50.57, 92.47, 98.93, 92.5, 61.69, 77.31, 79.42, 70.25, 88.72, 67.76, 89.13]
# [86.52, 95.64, 75.38, 55.26, 50.57, 92.47, 98.93, 92.5, 61.69, 77.31, 79.42, 70.25, 88.72, 67.76, 89.13, 73.91]
# ...

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la Fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 2')

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 14.95013372596521

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 13.362487270358953

# %%
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)

print("valores de la fabrica 1")
print("La media de la fabrica 1 es:",media1)
print("La mediana de la fabrica 1 es:",mediana1)
print("La moda de la fabrica 1 es:",moda1)
# Out:
# valores de la fabrica 1
# La media de la fabrica 1 es: 75.7684
# La mediana de la fabrica 1 es: 76.98500000000001
# La moda de la fabrica 1 es: 92.84

# %%
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
print("valores de la fabrica 2")
print("La media de la fabrica 2 es:",media2)
print("La mediana de la fabrica 2 es:",mediana2)
print("La moda de la fabrica 2 es:",moda2)
# Out:
# valores de la fabrica 2
# La media de la fabrica 2 es: 76.0819
# La mediana de la fabrica 2 es: 76.75999999999999
# La moda de la fabrica 2 es: 66.79

# %%
# Generar dos asuplot de rango por 2 columnas para desplegar los 2 histogramas
# una a lado de otra.
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda1, color='y' , linestyle='dashed' , linewidth=2, label='moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title("Produccion de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda2, color='y' , linestyle='dashed' , linewidth=2, label='moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title("Produccion de la fabrica 2")
plt.legend()
plt.show()

# %%
import seaborn as sns
sns.histplot( x = fabrica1, kde= True, kde_kws = {'bw_adjust': 0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>

# %%
plt. figure(figsize = (8,6) )
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt. axvline(media1, color='b', linestyle='dashed',linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1: .2f}')
plt. axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle= 'dashed',linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed',linewidth=2)
plt. xlabel ( 'Valor')
plt. ylabel( 'Frecuencia')
plt. title("Producción diaria de la fabrica 2")
plt. legend ()
plt. show()

# %%
plt. figure(figsize = (8,6) )
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt. axvline(media2, color='b', linestyle='dashed',linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2: .2f}')
plt. axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle= 'dashed',linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed',linewidth=2)
plt. xlabel ( 'Valor')
plt. ylabel( 'Frecuencia')
plt. title("Producción diaria de la fabrica 2")
plt. legend ()
plt. show()
